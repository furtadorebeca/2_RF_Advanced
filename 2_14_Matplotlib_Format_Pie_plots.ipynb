# %% [markdown]
# # Matplotlib Pie Plots
#
# **plt.pie()**

# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt 

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
# we're going to be plotting the variable job_work_from_home because it is a boolean field (2 possibilities), so it's suitable for a pie chart
df['job_work_from_home'].value_counts().plot(kind='pie', startangle=90) #start angle is used so that the true portion of the chart, starts at the top
plt.title('Work from Home Status')
plt.ylabel('')
plt.show()

# %%
# we're going to be plotting the variable job_work_from_home because it is a boolean field (2 possibilities), so it's suitable for a pie chart
df['job_work_from_home'].value_counts().plot(kind='pie', startangle=90, autopct='%1.2f%%') 
#autopct = relative percentage '1' means one or more digits; '2' means 2 decimals; '%%' shows the percentage symbol
plt.title('Work from Home Status')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Plot 3 Pie Charts
# - Work from home
# - Job degree required
# - Health Insurance offered

# %%
fig, ax = plt.subplots(1,3)

dict_column = {
    'job_work_from_home': 'Work from Home',
    'job_no_degree_mention': 'Job Degree Req.',
    'job_health_insurance': 'Health Insurance Offered'
}
for i, (column, title) in enumerate(dict_column.items()):
    ax[i].pie(df[column].value_counts(), startangle=90, autopct='%1.2f%%', labels=['False','True'])
    ax[i].set_title(title)

fig.tight_layout()
plt.show()
